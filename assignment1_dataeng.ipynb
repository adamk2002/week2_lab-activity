# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('placementdata.csv')
df.head(10)
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
# 5          6   7.0            0         2                         2
# 6          7   7.7            1         1                         1
# 7          8   7.7            2         1                         0
# 8          9   6.5            1         1                         0
# 9         10   7.8            1         3                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
# 5                 71               4.2                       Yes
# 6                 76               4.0                        No
# 7                 85               3.5                       Yes
# 8                 84               3.9                        No
# 9                 79               4.4                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# 1               Yes         78         82          Placed
# 2                No         79         80       NotPlaced
# 3               Yes         81         80          Placed
# 4               Yes         74         88          Placed
# 5                No         55         66       NotPlaced
# 6                No         62         65       NotPlaced
# 7               Yes         59         72       NotPlaced
# 8               Yes         75         71       NotPlaced
# 9               Yes         85         86          Placed

# %% [markdown]
# Placement Prediction Dataset: this dataset consists of 12 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
df.describe(include = 'all')
# Out:
#           StudentID          CGPA   Internships      Projects  \
# count   10000.00000  10000.000000  10000.000000  10000.000000
# unique          NaN           NaN           NaN           NaN
# top             NaN           NaN           NaN           NaN
# freq            NaN           NaN           NaN           NaN
# mean     5000.50000      7.698010      1.049200      2.026600
# std      2886.89568      0.640131      0.665901      0.867968
# min         1.00000      6.500000      0.000000      0.000000
# 25%      2500.75000      7.400000      1.000000      1.000000
# 50%      5000.50000      7.700000      1.000000      2.000000
# 75%      7500.25000      8.200000      1.000000      3.000000
# max     10000.00000      9.100000      2.000000      3.000000
#
#         Workshops/Certifications  AptitudeTestScore  SoftSkillsRating  \
# count               10000.000000       10000.000000      10000.000000
# unique                       NaN                NaN               NaN
# top                          NaN                NaN               NaN
# freq                         NaN                NaN               NaN
# mean                    1.013200          79.449900          4.323960
# std                     0.904272           8.159997          0.411622
# min                     0.000000          60.000000          3.000000
# 25%                     0.000000          73.000000          4.000000
# 50%                     1.000000          80.000000          4.400000
# 75%                     2.000000          87.000000          4.700000
# max                     3.000000          90.000000          4.800000
#
#        ExtracurricularActivities PlacementTraining     SSC_Marks  \
# count                      10000             10000  10000.000000
# unique                         2                 2           NaN
# top                          Yes               Yes           NaN
# freq                        5854              7318           NaN
# mean                         NaN               NaN     69.159400
# std                          NaN               NaN     10.430459
# min                          NaN               NaN     55.000000
# 25%                          NaN               NaN     59.000000
# 50%                          NaN               NaN     70.000000
# 75%                          NaN               NaN     78.000000
# max                          NaN               NaN     90.000000
#
#            HSC_Marks PlacementStatus
# count   10000.000000           10000
# unique           NaN               2
# top              NaN       NotPlaced
# freq             NaN            5803
# mean       74.501500             NaN
# std         8.919527             NaN
# min        57.000000             NaN
# 25%        67.000000             NaN
# 50%        73.000000             NaN
# 75%        83.000000             NaN
# max        88.000000             NaN

# %% [markdown]
# So what do we know at this point?
#
# Based on the dataset descriptive file, we were expecting our dataset to have a total of 12 columns: 3 text-based columns and 9 numeric columns. Also, we can see that all of our text-based columns are Binary Data or Boolean Data, meaning that each of these columns has two possible value (yes/no), (Notplaced/ Plcaed).
#
# Compared to the information that we gathered from the actual dataset, we see that the overall structure of the dataset matches the descriptive file. We also know at this point that the dataset has 10000 entries and there are no missing values within the dataset.

# %%
df.shape
# Out:
# (10000, 12)

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /opt/anaconda3/envs/msds/lib/python3.10/site-packages (2.9.10)

# %%
import psycopg2
print("psycopg2 installed successfully!")
# Out:
# psycopg2 installed successfully!

# %%
#!pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.37-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/msds/lib/python3.10/site-packages (from sqlalchemy) (4.12.2)
# Downloading SQLAlchemy-2.0.37-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.6 MB/s eta 0:00:00
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-2.0.37

# %%
from sqlalchemy import create_engine
print("SQLAlchemy imported successfully!")
# Out:
# SQLAlchemy imported successfully!

# %%
# Note:: The make sure you use the information from your specific PostgreSQL installation

# %%
host = r'127.0.0.1' # denotes that the db in a local installation
db = r'MSDS610' # db we just created
user = r'postgres' # using the postgres user for this demo
pw = r'adamkhay' # this is the password established during installation
port = r'5432' # default port estabalished during install
schema = r'raw' # schema we just created

# %%
db_conn = create_engine("postgresql://{}:{}@{}:{}/{}".format(user, pw, host, port, db))

# %%
sql="select tables.table_name from information_schema.tables where (table_schema ='"+schema+"')order by 1;"
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df
# Out:
# Empty DataFrame
# Columns: [table_name]
# Index: []

# %% [markdown]
# ### Time to load some data
# We need to define a name for the table that we are above to create in our database.

# %%
table_name = r'placement_data'

# %%
df.to_sql(table_name, con=db_conn, if_exists='replace', index=False, schema=schema, chunksize=1000, method='multi')
# Out:
# 10000

# %%
tbl_df = pd.read_sql(sql, db_conn, index_col=None)
tbl_df
# Out:
#        table_name
# 0  placement_data

# %% [markdown]
# Retrieving data
# Okay, time to actually verify that our data was loaded to the database. For this, I'll retreive the entire dataset.

# %%
sql=r'SELECT * FROM ' + schema + '.' + table_name
df_check = pd.read_sql(sql, db_conn, index_col=None)

# %%
df_check.head(10)
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
# 5          6   7.0            0         2                         2
# 6          7   7.7            1         1                         1
# 7          8   7.7            2         1                         0
# 8          9   6.5            1         1                         0
# 9         10   7.8            1         3                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
# 5                 71               4.2                       Yes
# 6                 76               4.0                        No
# 7                 85               3.5                       Yes
# 8                 84               3.9                        No
# 9                 79               4.4                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# 1               Yes         78         82          Placed
# 2                No         79         80       NotPlaced
# 3               Yes         81         80          Placed
# 4               Yes         74         88          Placed
# 5                No         55         66       NotPlaced
# 6                No         62         65       NotPlaced
# 7               Yes         59         72       NotPlaced
# 8               Yes         75         71       NotPlaced
# 9               Yes         85         86          Placed
